# %% [markdown]
# # Project - CO2 Per Capita

# %% [markdown]
# ![Data Science Workflow](img/ds-workflow.png)

# %% [markdown]
# ## Goal of Project
# - Explore how Data Visualization can help present findings with a message
# - We will explore the CO2 per capita dataset
# - It will be your task to what kind of message you want the receiver to get
# - NOTE: We still have limited skills, hence, we must limit our ambitions in our analysis

# %% [markdown]
# ## Step 1: Acquire
# - Explore problem
# - Identify data
# - Import data

# %% [markdown]
# ### Step 1.a: Import libraries
# - Execute the cell below (SHIFT + ENTER)

# %%
import pandas as pd 
import matplotlib.pylab as plt

# %% [markdown]
# ### Step 1.b: Read the data
# - Use ```pd.read_csv()``` to read the file `files/WorldBank-ATM.CO2E.PC_DS2.csv`
# - NOTE: Remember to assign the result to a variable (e.g., ```data```)
# - NOTE: Use ```index_col=0``` as argument to set the index column.
# - Apply ```.head()``` on the data to see all is as expected

# %%
df = pd.read_csv('files/WorldBank-ATM.CO2E.PC_DS2.csv')
df.head()
# Out:
#    Year         ABW       AFE       AFG       AFW       AGO       ALB  AND  \
# 0  1960  204.631696  0.906060  0.046057  0.090880  0.100835  1.258195  NaN
# 1  1961  208.837879  0.922474  0.053589  0.095283  0.082204  1.374186  NaN
# 2  1962  226.081890  0.930816  0.073721  0.096612  0.210533  1.439956  NaN
# 3  1963  214.785217  0.940570  0.074161  0.112376  0.202739  1.181681  NaN
# 4  1964  207.626699  0.996033  0.086174  0.133258  0.213562  1.111742  NaN
#
#         ARB       ARE  ...  VIR       VNM       VUT       WLD       WSM  XKX  \
# 0  0.609268  0.119037  ...  NaN  0.181947       NaN  3.121158  0.135031  NaN
# 1  0.662618  0.109136  ...  NaN  0.183099       NaN  3.068090  0.163542  NaN
# 2  0.727117  0.163542  ...  NaN  0.217694  0.595002  3.114839  0.158377  NaN
# 3  0.853116  0.175833  ...  NaN  0.196997  0.471849  3.221195  0.184037  NaN
# 4  0.972381  0.132815  ...  NaN  0.209870  0.864427  3.324046  0.208106  NaN
#
#         YEM       ZAF       ZMB       ZWE
# 0  0.011038  5.727223       NaN       NaN
# 1  0.013599  5.832621       NaN       NaN
# 2  0.012729  5.887168       NaN       NaN
# 3  0.014518  5.961337       NaN       NaN
# 4  0.017550  6.332343  0.946606  1.034904
#
# [5 rows x 267 columns]

# %% [markdown]
# ### Step 1.c: Size of data
# - The columns represent countries and rows years
# - Apply ```.shape``` on the DataFrame to see if data is as expected

# %%
df.shape
# Out:
# (59, 267)

# %% [markdown]
# ## Step 2: Prepare
# - Explore data
# - Visualize ideas
# - Cleaning data

# %% [markdown]
# ### Step 2.a: Check the data types
# - This step tells you if some numeric column is not represented numeric.
# - Get the data types by ```.dtypes```
# - We expect all data to numeric
# - Try out ```.info()``` to get an overview.

# %%
df.dtypes
# Out:
# Year      int64
# ABW     float64
# AFE     float64
# AFG     float64
# AFW     float64
#          ...
# XKX     float64
# YEM     float64
# ZAF     float64
# ZMB     float64
# ZWE     float64
# Length: 267, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Columns: 267 entries, Year to ZWE
# dtypes: float64(266), int64(1)
# memory usage: 123.2 KB

# %% [markdown]
# ### Step 2.b: Check for null (missing) values
# - Data often is missing entries - there can be many reasons for this
# - We need to deal with that (will do later in course)
# - Use ```.isnull().any()```
# - This is expected - but we need to be aware of it

# %%
df.isnull().any()
# Out:
# Year    False
# ABW      True
# AFE     False
# AFG     False
# AFW     False
#         ...
# XKX      True
# YEM     False
# ZAF     False
# ZMB      True
# ZWE      True
# Length: 267, dtype: bool

# %% [markdown]
# ### Step 2.c: Visualize number of missing data points
# - To get an idea of the maginitude of the problem you can visualize the number of missing rows for each country.
# - ```.isnull()``` identifies missing values
# - ```.isnull().sum()``` counts the number of missing values per country
# - ```.isnull().sum().plot.hist()``` plots how many countries have missing values in ranges

# %%
df.isnull()
# Out:
#      Year    ABW    AFE    AFG    AFW    AGO    ALB    AND    ARB    ARE  ...  \
# 0   False  False  False  False  False  False  False   True  False  False  ...
# 1   False  False  False  False  False  False  False   True  False  False  ...
# 2   False  False  False  False  False  False  False   True  False  False  ...
# 3   False  False  False  False  False  False  False   True  False  False  ...
# 4   False  False  False  False  False  False  False   True  False  False  ...
# 5   False  False  False  False  False  False  False   True  False  False  ...
# 6   False  False  False  False  False  False  False   True  False  False  ...
# 7   False  False  False  False  False  False  False   True  False  False  ...
# 8   False  False  False  False  False  False  False   True  False  False  ...
# 9   False  False  False  False  False  False  False   True  False  False  ...
# 10  False  False  False  False  False  False  False   True  False  False  ...
# 11  False  False  False  False  False  False  False   True  False  False  ...
# 12  False  False  False  False  False  False  False   True  False  False  ...
# 13  False  False  False  False  False  False  False   True  False  False  ...
# 14  False  False  False  False  False  False  False   True  False  False  ...
# 15  False  False  False  False  False  False  False   True  False  False  ...
# 16  False  False  False  False  False  False  False   True  False  False  ...
# 17  False  False  False  False  False  False  False   True  False  False  ...
# 18  False  False  False  False  False  False  False   True  False  False  ...
# 19  False  False  False  False  False  False  False   True  False  False  ...
# 20  False  False  False  False  False  False  False   True  False  False  ...
# 21  False  False  False  False  False  False  False   True  False  False  ...
# 22  False  False  False  False  False  False  False   True  False  False  ...
# 23  False  False  False  False  False  False  False   True  False  False  ...
# 24  False  False  False  False  False  False  False   True  False  False  ...
# 25  False  False  False  False  False  False  False   True  False  False  ...
# 26  False  False  False  False  False  False  False   True  False  False  ...
# 27  False  False  False  False  False  False  False   True  False  False  ...
# 28  False  False  False  False  False  False  False   True  False  False  ...
# 29  False  False  False  False  False  False  False   True  False  False  ...
# 30  False   True  False  False  False  False  False  False  False  False  ...
# 31  False   True  False  False  False  False  False  False  False  False  ...
# 32  False   True  False  False  False  False  False  False  False  False  ...
# 33  False   True  False  False  False  False  False  False  False  False  ...
# 34  False   True  False  False  False  False  False  False  False  False  ...
# 35  False   True  False  False  False  False  False  False  False  False  ...
# 36  False   True  False  False  False  False  False  False  False  False  ...
# 37  False   True  False  False  False  False  False  False  False  False  ...
# 38  False   True  False  False  False  False  False  False  False  False  ...
# 39  False   True  False  False  False  False  False  False  False  False  ...
# 40  False   True  False  False  False  False  False  False  False  False  ...
# 41  False   True  False  False  False  False  False  False  False  False  ...
# 42  False   True  False  False  False  False  False  False  False  False  ...
# 43  False   True  False  False  False  False  False  False  False  False  ...
# 44  False   True  False  False  False  False  False  False  False  False  ...
# 45  False   True  False  False  False  False  False  False  False  False  ...
# 46  False   True  False  False  False  False  False  False  False  False  ...
# 47  False   True  False  False  False  False  False  False  False  False  ...
# 48  False   True  False  False  False  False  False  False  False  False  ...
# 49  False   True  False  False  False  False  False  False  False  False  ...
# 50  False   True  False  False  False  False  False  False  False  False  ...
# 51  False   True  False  False  False  False  False  False  False  False  ...
# 52  False   True  False  False  False  False  False  False  False  False  ...
# 53  False   True  False  False  False  False  False  False  False  False  ...
# 54  False   True  False  False  False  False  False  False  False  False  ...
# 55  False   True  False  False  False  False  False  False  False  False  ...
# 56  False   True  False  False  False  False  False  False  False  False  ...
# 57  False   True  False  False  False  False  False  False  False  False  ...
# 58  False   True  False  False  False  False  False  False  False  False  ...
#
#      VIR    VNM    VUT    WLD    WSM   XKX    YEM    ZAF    ZMB    ZWE
# 0   True  False   True  False  False  True  False  False   True   True
# 1   True  False   True  False  False  True  False  False   True   True
# 2   True  False  False  False  False  True  False  False   True   True
# 3   True  False  False  False  False  True  False  False   True   True
# 4   True  False  False  False  False  True  False  False  False  False
# 5   True  False  False  False  False  True  False  False  False  False
# 6   True  False  False  False  False  True  False  False  False  False
# 7   True  False  False  False  False  True  False  False  False  False
# 8   True  False  False  False  False  True  False  False  False  False
# 9   True  False  False  False  False  True  False  False  False  False
# 10  True  False  False  False  False  True  False  False  False  False
# 11  True  False  False  False  False  True  False  False  False  False
# 12  True  False  False  False  False  True  False  False  False  False
# 13  True  False  False  False  False  True  False  False  False  False
# 14  True  False  False  False  False  True  False  False  False  False
# 15  True  False  False  False  False  True  False  False  False  False
# 16  True  False  False  False  False  True  False  False  False  False
# 17  True  False  False  False  False  True  False  False  False  False
# 18  True  False  False  False  False  True  False  False  False  False
# 19  True  False  False  False  False  True  False  False  False  False
# 20  True  False  False  False  False  True  False  False  False  False
# 21  True  False  False  False  False  True  False  False  False  False
# 22  True  False  False  False  False  True  False  False  False  False
# 23  True  False  False  False  False  True  False  False  False  False
# 24  True  False  False  False  False  True  False  False  False  False
# 25  True  False  False  False  False  True  False  False  False  False
# 26  True  False  False  False  False  True  False  False  False  False
# 27  True  False  False  False  False  True  False  False  False  False
# 28  True  False  False  False  False  True  False  False  False  False
# 29  True  False  False  False  False  True  False  False  False  False
# 30  True  False  False  False  False  True  False  False  False  False
# 31  True  False  False  False  False  True  False  False  False  False
# 32  True  False  False  False  False  True  False  False  False  False
# 33  True  False  False  False  False  True  False  False  False  False
# 34  True  False  False  False  False  True  False  False  False  False
# 35  True  False  False  False  False  True  False  False  False  False
# 36  True  False  False  False  False  True  False  False  False  False
# 37  True  False  False  False  False  True  False  False  False  False
# 38  True  False  False  False  False  True  False  False  False  False
# 39  True  False  False  False  False  True  False  False  False  False
# 40  True  False  False  False  False  True  False  False  False  False
# 41  True  False  False  False  False  True  False  False  False  False
# 42  True  False  False  False  False  True  False  False  False  False
# 43  True  False  False  False  False  True  False  False  False  False
# 44  True  False  False  False  False  True  False  False  False  False
# 45  True  False  False  False  False  True  False  False  False  False
# 46  True  False  False  False  False  True  False  False  False  False
# 47  True  False  False  False  False  True  False  False  False  False
# 48  True  False  False  False  False  True  False  False  False  False
# 49  True  False  False  False  False  True  False  False  False  False
# 50  True  False  False  False  False  True  False  False  False  False
# 51  True  False  False  False  False  True  False  False  False  False
# 52  True  False  False  False  False  True  False  False  False  False
# 53  True  False  False  False  False  True  False  False  False  False
# 54  True  False  False  False  False  True  False  False  False  False
# 55  True  False  False  False  False  True  False  False  False  False
# 56  True  False  False  False  False  True  False  False  False  False
# 57  True  False  False  False  False  True  False  False  False  False
# 58  True  False  False  False  False  True  False  False  False  False
#
# [59 rows x 267 columns]

# %%
df.isnull().sum()
# Out:
# Year     0
# ABW     29
# AFE      0
# AFG      0
# AFW      0
#         ..
# XKX     59
# YEM      0
# ZAF      0
# ZMB      4
# ZWE      4
# Length: 267, dtype: int64

# %%
df.isnull().sum().plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# ### Step 2.d: Clean data
# - A simple way to clean data is to remove columns with missing data
# - Use ```.dropna(axis='columns')``` to remove columns with missing data
# - Check how may columns are left
#     - HINT: apply ```len(...)``` on the DataFrame columns

# %%
df.head()
# Out:
#    Year         ABW       AFE       AFG       AFW       AGO       ALB  AND  \
# 0  1960  204.631696  0.906060  0.046057  0.090880  0.100835  1.258195  NaN
# 1  1961  208.837879  0.922474  0.053589  0.095283  0.082204  1.374186  NaN
# 2  1962  226.081890  0.930816  0.073721  0.096612  0.210533  1.439956  NaN
# 3  1963  214.785217  0.940570  0.074161  0.112376  0.202739  1.181681  NaN
# 4  1964  207.626699  0.996033  0.086174  0.133258  0.213562  1.111742  NaN
#
#         ARB       ARE  ...  VIR       VNM       VUT       WLD       WSM  XKX  \
# 0  0.609268  0.119037  ...  NaN  0.181947       NaN  3.121158  0.135031  NaN
# 1  0.662618  0.109136  ...  NaN  0.183099       NaN  3.068090  0.163542  NaN
# 2  0.727117  0.163542  ...  NaN  0.217694  0.595002  3.114839  0.158377  NaN
# 3  0.853116  0.175833  ...  NaN  0.196997  0.471849  3.221195  0.184037  NaN
# 4  0.972381  0.132815  ...  NaN  0.209870  0.864427  3.324046  0.208106  NaN
#
#         YEM       ZAF       ZMB       ZWE
# 0  0.011038  5.727223       NaN       NaN
# 1  0.013599  5.832621       NaN       NaN
# 2  0.012729  5.887168       NaN       NaN
# 3  0.014518  5.961337       NaN       NaN
# 4  0.017550  6.332343  0.946606  1.034904
#
# [5 rows x 267 columns]

# %%
df.isna().count().sum()
# Out:
# 15753

# %%
df = pd.read_csv('files/WorldBank-ATM.CO2E.PC_DS2.csv',index_col=0)
df.head()
# Out:
#              ABW       AFE       AFG       AFW       AGO       ALB  AND  \
# Year
# 1960  204.631696  0.906060  0.046057  0.090880  0.100835  1.258195  NaN
# 1961  208.837879  0.922474  0.053589  0.095283  0.082204  1.374186  NaN
# 1962  226.081890  0.930816  0.073721  0.096612  0.210533  1.439956  NaN
# 1963  214.785217  0.940570  0.074161  0.112376  0.202739  1.181681  NaN
# 1964  207.626699  0.996033  0.086174  0.133258  0.213562  1.111742  NaN
#
#            ARB       ARE       ARG  ...  VIR       VNM       VUT       WLD  \
# Year                                ...
# 1960  0.609268  0.119037  2.383343  ...  NaN  0.181947       NaN  3.121158
# 1961  0.662618  0.109136  2.458551  ...  NaN  0.183099       NaN  3.068090
# 1962  0.727117  0.163542  2.538447  ...  NaN  0.217694  0.595002  3.114839
# 1963  0.853116  0.175833  2.330685  ...  NaN  0.196997  0.471849  3.221195
# 1964  0.972381  0.132815  2.553442  ...  NaN  0.209870  0.864427  3.324046
#
#            WSM  XKX       YEM       ZAF       ZMB       ZWE
# Year
# 1960  0.135031  NaN  0.011038  5.727223       NaN       NaN
# 1961  0.163542  NaN  0.013599  5.832621       NaN       NaN
# 1962  0.158377  NaN  0.012729  5.887168       NaN       NaN
# 1963  0.184037  NaN  0.014518  5.961337       NaN       NaN
# 1964  0.208106  NaN  0.017550  6.332343  0.946606  1.034904
#
# [5 rows x 266 columns]

# %%
df.isna().count().sum()
# Out:
# 15694

# %%
clean_data1 = df.dropna(axis = 1)
clean_data1.head()
# len(df.columns),len(clean_data.columns)
# Out:
#            AFE       AFG       AFW       AGO       ALB       ARB       ARE  \
# Year
# 1960  0.906060  0.046057  0.090880  0.100835  1.258195  0.609268  0.119037
# 1961  0.922474  0.053589  0.095283  0.082204  1.374186  0.662618  0.109136
# 1962  0.930816  0.073721  0.096612  0.210533  1.439956  0.727117  0.163542
# 1963  0.940570  0.074161  0.112376  0.202739  1.181681  0.853116  0.175833
# 1964  0.996033  0.086174  0.133258  0.213562  1.111742  0.972381  0.132815
#
#            ARG       ATG       AUS  ...       UMC       URY        USA  \
# Year                                ...
# 1960  2.383343  0.677418  8.582937  ...  2.573291  1.701585  15.999779
# 1961  2.458551  0.866667  8.641569  ...  2.408432  1.602728  15.681256
# 1962  2.538447  1.838457  8.835688  ...  2.370116  1.540660  16.013937
# 1963  2.330685  1.487469  9.226440  ...  2.435563  1.639287  16.482762
# 1964  2.553442  1.590448  9.759073  ...  2.523331  1.710104  16.968119
#
#            VCT       VEN       VNM       WLD       WSM       YEM       ZAF
# Year
# 1960  0.135865  7.009414  0.181947  3.121158  0.135031  0.011038  5.727223
# 1961  0.133884  6.153191  0.183099  3.068090  0.163542  0.013599  5.832621
# 1962  0.132162  6.188716  0.217694  3.114839  0.158377  0.012729  5.887168
# 1963  0.174204  6.208593  0.196997  3.221195  0.184037  0.014518  5.961337
# 1964  0.215409  6.041541  0.209870  3.324046  0.208106  0.017550  6.332343
#
# [5 rows x 191 columns]

# %%
clean_data = df.copy()
clean_data.head()
# Out:
#            AFE       AFG       AFW       AGO       ALB       ARB       ARE  \
# Year
# 1960  0.906060  0.046057  0.090880  0.100835  1.258195  0.609268  0.119037
# 1961  0.922474  0.053589  0.095283  0.082204  1.374186  0.662618  0.109136
# 1962  0.930816  0.073721  0.096612  0.210533  1.439956  0.727117  0.163542
# 1963  0.940570  0.074161  0.112376  0.202739  1.181681  0.853116  0.175833
# 1964  0.996033  0.086174  0.133258  0.213562  1.111742  0.972381  0.132815
#
#            ARG       ATG       AUS  ...       UMC       URY        USA  \
# Year                                ...
# 1960  2.383343  0.677418  8.582937  ...  2.573291  1.701585  15.999779
# 1961  2.458551  0.866667  8.641569  ...  2.408432  1.602728  15.681256
# 1962  2.538447  1.838457  8.835688  ...  2.370116  1.540660  16.013937
# 1963  2.330685  1.487469  9.226440  ...  2.435563  1.639287  16.482762
# 1964  2.553442  1.590448  9.759073  ...  2.523331  1.710104  16.968119
#
#            VCT       VEN       VNM       WLD       WSM       YEM       ZAF
# Year
# 1960  0.135865  7.009414  0.181947  3.121158  0.135031  0.011038  5.727223
# 1961  0.133884  6.153191  0.183099  3.068090  0.163542  0.013599  5.832621
# 1962  0.132162  6.188716  0.217694  3.114839  0.158377  0.012729  5.887168
# 1963  0.174204  6.208593  0.196997  3.221195  0.184037  0.014518  5.961337
# 1964  0.215409  6.041541  0.209870  3.324046  0.208106  0.017550  6.332343
#
# [5 rows x 191 columns]

# %%
df.isna().count().sum()
# Out:
# 11269

# %%
df.dropna(axis=0,inplace=True)
df.isna().count().sum()
# Out:
# 11269

# %%
df.isna().count()
# Out:
# AFE    59
# AFG    59
# AFW    59
# AGO    59
# ALB    59
#        ..
# VNM    59
# WLD    59
# WSM    59
# YEM    59
# ZAF    59
# Length: 191, dtype: int64

# %%
df.shape
# Out:
# (59, 191)

# %%
df.isnull().count().sum()
# Out:
# 11269

# %% [markdown]
# ## Step 3: Analyze
# - Feature selection
# - Model selection
# - Analyze data

# %% [markdown]
# ### Step 3.a: Percentage change 20 years
# - Calculate the change in CO2 per capita from 1998 to 2018
#     - HINT: Formula is (value in 2018 - value in 1998) / value in 1998
#     - This can be calculated on all rows simultaneously
#         - ```(data_clean.loc[2018] - data_clean.loc[1998])/data_clean.loc[1998]``` Assuming the data is in ```data_clean```

# %%
df.head()
# Out:
#            AFE       AFG       AFW       AGO       ALB       ARB       ARE  \
# Year
# 1960  0.906060  0.046057  0.090880  0.100835  1.258195  0.609268  0.119037
# 1961  0.922474  0.053589  0.095283  0.082204  1.374186  0.662618  0.109136
# 1962  0.930816  0.073721  0.096612  0.210533  1.439956  0.727117  0.163542
# 1963  0.940570  0.074161  0.112376  0.202739  1.181681  0.853116  0.175833
# 1964  0.996033  0.086174  0.133258  0.213562  1.111742  0.972381  0.132815
#
#            ARG       ATG       AUS  ...       UMC       URY        USA  \
# Year                                ...
# 1960  2.383343  0.677418  8.582937  ...  2.573291  1.701585  15.999779
# 1961  2.458551  0.866667  8.641569  ...  2.408432  1.602728  15.681256
# 1962  2.538447  1.838457  8.835688  ...  2.370116  1.540660  16.013937
# 1963  2.330685  1.487469  9.226440  ...  2.435563  1.639287  16.482762
# 1964  2.553442  1.590448  9.759073  ...  2.523331  1.710104  16.968119
#
#            VCT       VEN       VNM       WLD       WSM       YEM       ZAF
# Year
# 1960  0.135865  7.009414  0.181947  3.121158  0.135031  0.011038  5.727223
# 1961  0.133884  6.153191  0.183099  3.068090  0.163542  0.013599  5.832621
# 1962  0.132162  6.188716  0.217694  3.114839  0.158377  0.012729  5.887168
# 1963  0.174204  6.208593  0.196997  3.221195  0.184037  0.014518  5.961337
# 1964  0.215409  6.041541  0.209870  3.324046  0.208106  0.017550  6.332343
#
# [5 rows x 191 columns]

# %%
df.loc[2018]
# Out:
# AFE    0.933541
# AFG    0.200151
# AFW    0.515544
# AGO    0.887380
# ALB    1.939732
#          ...
# VNM    2.698806
# WLD    4.483524
# WSM    1.631588
# YEM    0.326682
# ZAF    7.496645
# Name: 2018, Length: 191, dtype: float64

# %%
data_clean = clean_data

# %%
data_plt = (data_clean.loc[2018] - data_clean.loc[1998])/data_clean.loc[1998]

# %%
data
# Out:
# AFE   -0.037269
# AFG    2.762415
# AFW    0.116810
# AGO    0.198752
# ALB    2.371394
#          ...
# VNM    3.698443
# WLD    0.185926
# WSM    1.014300
# YEM   -0.541857
# ZAF    0.104416
# Length: 191, dtype: float64

# %% [markdown]
# ### Step 3.b: Describe the data
# - A great way to understand data is to apply ```.describe()```
# - How does this help you to understand data?

# %%
data_plt.describe()
# Out:
# count    191.000000
# mean       0.494745
# std        1.341795
# min       -0.737721
# 25%       -0.101786
# 50%        0.198752
# 75%        0.643839
# max       15.694284
# dtype: float64

# %% [markdown]
# ### Step 3.c: Visualization of data
# - This helps you to understand data better
# - We start with a histogram ```.plot.hist(bins=30)```
# - Try with a Pie Chart on values below 0
#     - HINT: Use ```(data_plot < 0).value_counts()``` (assuming data is in ```data_plot```)
#     - Chart: ```.plot.pie(colors=['r', 'g'], labels=['>= 0', '< 0'], title='Title', ylabel='label', autopct='%1.1f%%')```
# - Play around with other visualizations

# %%
data.plot.hist(bins=30)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
(data_plt < 0).value_counts()
# Out:
# False    123
# True      68
# dtype: int64

# %%
(data_plt < 0).value_counts().plot.pie(colors=['y', 'g'], labels=['>= 0', '< 0'], title='Title', ylabel='label', autopct='%1.1f%%')
# Out:
# <AxesSubplot: title={'center': 'Title'}, ylabel='label'>

# %% [markdown]
# ## Step 4: Report
# - Present findings
# - Visualize results
# - Credibility counts

# %% [markdown]
# ### Step 4.a: Present a chart
# - The goal here is to present your message
# - Visualize one chart
# - Add a headline (title) to give the audience a message

# %%
(data_plt < 0).value_counts().plot.pie(colors=['y', 'g'], labels=['>= 0', '< 0'], title='Countries with decrease in co2 per capita', ylabel='20- years co2 capita development ', autopct='%1.1f%%')
# Out:
# <AxesSubplot: title={'center': 'Countries with decrease in co2 per capita'}, ylabel='20- years co2 capita development '>

# %% [markdown]
# ## Step 5: Actions
# - Use insights
# - Measure impact
# - Main goal

# %% [markdown]
# ### Step 5.a: Actions
# - Propose actions
