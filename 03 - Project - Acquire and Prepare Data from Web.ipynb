# %% [markdown]
# # Project - Acquire and Prepare Data from Web

# %% [markdown]
# ![Data Science Workflow](img/ds-workflow.png)

# %% [markdown]
# ## Goal of Project
# - This project will focus on Step 1 and 2 (**Acquire** and **Prepare**)
# - We will read raw data that needs Data Wrangling to prepare
# - The process we follow demonstrates how a Data Scientist works

# %% [markdown]
# ## Step 1: Acquire
# - Explore problem
# - Identify data
# - Import data

# %% [markdown]
# ### Step 1.a: Import libraries
# - Execute the cell below (SHIFT + ENTER)

# %%
import pandas as pd

# %%
df = pd.read_csv('files/fundraising.csv')

# %%
df.head()
# Out:
#         Year Source        Revenue       Expenses    Asset rise   Total assets
# 0  2019/2020    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 1  2018/2019    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 2  2017/2018    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 3  2016/2017    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 4  2015/2016    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795

# %% [markdown]
# ### Step 1.b: Retrieve/Read the data
# - There are two options to get data
# #### Option 1: Directly from wikipedia
# - Assign variable ```url = "https://en.wikipedia.org/wiki/Wikipedia:Fundraising_statistics"```
# - Retrieve the data ```tables = pd.read_html(url)```
# - Assign the first DataFrame to a variable
#     - HINT: ```tables``` is a list DataFrame containing all the data
#
# #### Option 2: From csv file (if option 1 fails)
# - Use ```pd.read_csv()``` to read the file `files/fundraising.csv`
# - NOTE: Remember to assign the result to a variable (e.g., ```data```)
# - Apply ```.head()``` on the data to see all is as expected

# %%
df = pd.read_csv('files/fundraising.csv')
df
# Out:
#          Year Source        Revenue       Expenses    Asset rise  \
# 0   2019/2020    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300
# 1   2018/2019    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855
# 2   2017/2018    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373
# 3   2016/2017    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402
# 4   2015/2016    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497
# 5   2014/2015    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277
# 6   2013/2014    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897
# 7   2012/2013    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066
# 8   2011/2012    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914
# 9   2010/2011    PDF   $ 24,785,092   $ 17,889,794   $ 9,649,413
# 10  2009/2010    PDF   $ 17,979,312   $ 10,266,793   $ 6,310,964
# 11  2008/2009    PDF    $ 8,658,006    $ 5,617,236   $ 3,053,599
# 12  2007/2008    PDF    $ 5,032,981    $ 3,540,724   $ 3,519,886
# 13  2006/2007    PDF    $ 2,734,909    $ 2,077,843     $ 654,066
# 14  2005/2006    PDF    $ 1,508,039      $ 791,907     $ 736,132
# 15  2004/2005    PDF      $ 379,088      $ 177,670     $ 211,418
# 16  2003/2004    PDF       $ 80,129       $ 23,463      $ 56,666
#
#      Total assets
# 0   $ 180,315,725
# 1   $ 165,641,425
# 2   $ 134,949,570
# 3   $ 113,330,197
# 4    $ 91,782,795
# 5    $ 77,820,298
# 6    $ 53,475,021
# 7    $ 45,189,124
# 8    $ 34,929,058
# 9    $ 24,192,144
# 10   $ 14,542,731
# 11    $ 8,231,767
# 12    $ 5,178,168
# 13    $ 1,658,282
# 14    $ 1,004,216
# 15      $ 268,084
# 16       $ 56,666

# %% [markdown]
# ## Step 2: Prepare
# - Explore data
# - Visualize ideas
# - Cleaning data

# %% [markdown]
# ### Step 2.a: Check the data types
# - This step tells you if some numeric column is not represented numeric.
# - Get the data types by ```.dtypes```

# %%
df.dtypes
# Out:
# Year            object
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# dtype: object

# %% [markdown]
# ### Step 2.b: Check for null (missing) values
# - Data often is missing entries - there can be many reasons for this
# - We need to deal with that (will do later in course)
# - Use ```.isna().any()```

# %%
df.isnull().any()
# Out:
# Year            False
# Source          False
# Revenue         False
# Expenses        False
# Asset rise      False
# Total assets    False
# dtype: bool

# %% [markdown]
# ### Step 2.c: Delete Source Column
# - The Column Source adds no value for further investigations
# - You can delete it by
#     - ```del data['Source']```

# %%
del df['Source']

# %%
df
# Out:
#          Year        Revenue       Expenses    Asset rise   Total assets
# 0   2019/2020  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 1   2018/2019  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 2   2017/2018  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 3   2016/2017   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 4   2015/2016   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 5   2014/2015   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 6   2013/2014   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 7   2012/2013   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 8   2011/2012   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 9   2010/2011   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# 10  2009/2010   $ 17,979,312   $ 10,266,793   $ 6,310,964   $ 14,542,731
# 11  2008/2009    $ 8,658,006    $ 5,617,236   $ 3,053,599    $ 8,231,767
# 12  2007/2008    $ 5,032,981    $ 3,540,724   $ 3,519,886    $ 5,178,168
# 13  2006/2007    $ 2,734,909    $ 2,077,843     $ 654,066    $ 1,658,282
# 14  2005/2006    $ 1,508,039      $ 791,907     $ 736,132    $ 1,004,216
# 15  2004/2005      $ 379,088      $ 177,670     $ 211,418      $ 268,084
# 16  2003/2004       $ 80,129       $ 23,463      $ 56,666       $ 56,666

# %% [markdown]
# ### Step 2.d: Convert Year column to numeric
# - All the strings in years are formatted: 'YYYY/YYYY'
# - To get the last year as string: ```data['Year'].str[-4:]```
# - To convert that to numeric use: ```pd.to_numeric(...)```
#     - HINT: You can assign the column directly

# %%
df.head(3)
# Out:
#         Year        Revenue       Expenses    Asset rise   Total assets
# 0  2019/2020  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 1  2018/2019  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 2  2017/2018  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570

# %%
df['Year']= df['Year'].str[-4:]

# %%
df
# Out:
#     Year        Revenue       Expenses    Asset rise   Total assets
# 0   2020  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 1   2019  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 2   2018  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 3   2017   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 4   2016   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 5   2015   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 6   2014   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 7   2013   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 8   2012   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# 9   2011   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144
# 10  2010   $ 17,979,312   $ 10,266,793   $ 6,310,964   $ 14,542,731
# 11  2009    $ 8,658,006    $ 5,617,236   $ 3,053,599    $ 8,231,767
# 12  2008    $ 5,032,981    $ 3,540,724   $ 3,519,886    $ 5,178,168
# 13  2007    $ 2,734,909    $ 2,077,843     $ 654,066    $ 1,658,282
# 14  2006    $ 1,508,039      $ 791,907     $ 736,132    $ 1,004,216
# 15  2005      $ 379,088      $ 177,670     $ 211,418      $ 268,084
# 16  2004       $ 80,129       $ 23,463      $ 56,666       $ 56,666

# %%
df['year'] = pd.to_numeric(df['Year'])
df.dtypes
# Out:
# Year            object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# year             int64
# dtype: object

# %% [markdown]
# ### Step 2.e: Set Year to index
# - To change a column to be the index use: ```data.set_index('Year', inplace=True)```
# - Also sort the index in correct order: ```data.sort_index(inplace=True)```

# %%
df.set_index('Year', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.set_index('Year', inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:6009, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6006                 missing.append(col)
#    6008 if missing:
# -> 6009     raise KeyError(f"None of {missing} are in the columns")
#    6011 if inplace:
#    6012     frame = self
#
# KeyError: "None of ['Year'] are in the columns"

# %%
df.head()
# Out:
#           Revenue     Expenses   Asset rise Total assets  year
# Year
# 2004     $ 80,129     $ 23,463     $ 56,666     $ 56,666  2004
# 2005    $ 379,088    $ 177,670    $ 211,418    $ 268,084  2005
# 2006  $ 1,508,039    $ 791,907    $ 736,132  $ 1,004,216  2006
# 2007  $ 2,734,909  $ 2,077,843    $ 654,066  $ 1,658,282  2007
# 2008  $ 5,032,981  $ 3,540,724  $ 3,519,886  $ 5,178,168  2008

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#             Revenue       Expenses    Asset rise   Total assets  year
# Year
# 2004       $ 80,129       $ 23,463      $ 56,666       $ 56,666  2004
# 2005      $ 379,088      $ 177,670     $ 211,418      $ 268,084  2005
# 2006    $ 1,508,039      $ 791,907     $ 736,132    $ 1,004,216  2006
# 2007    $ 2,734,909    $ 2,077,843     $ 654,066    $ 1,658,282  2007
# 2008    $ 5,032,981    $ 3,540,724   $ 3,519,886    $ 5,178,168  2008
# 2009    $ 8,658,006    $ 5,617,236   $ 3,053,599    $ 8,231,767  2009
# 2010   $ 17,979,312   $ 10,266,793   $ 6,310,964   $ 14,542,731  2010
# 2011   $ 24,785,092   $ 17,889,794   $ 9,649,413   $ 24,192,144  2011
# 2012   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058  2012
# 2013   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124  2013
# 2014   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021  2014
# 2015   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298  2015
# 2016   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795  2016
# 2017   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197  2017
# 2018  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570  2018
# 2019  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425  2019
# 2020  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725  2020

# %% [markdown]
# ### Step 2.f: Convert the remaining columns to numeric
# - Remember the steps from the lesson
#     - ```.str[2:]``` to remove the first two characters ('\$ ')
#     - ```.str.replace(',', '')``` to remove commas
#     - ```pd.to_numeric(...)``` converts string (containing well-formed number) to the numeric value
# - Try to do it directly column by column

# %%
# df['Revenue'] = pd.to_numeric(df['Revenue'].str[2:].str.replace(',',''))
# df['Expenses'] = pd.to_numeric(df['Expenses'].str[2:].str.replace(',',''))
df['Asset rise'] = pd.to_numeric(df['Asset rise'].str[2:].str.replace(',',''))
df['Total assets'] = pd.to_numeric(df['Total assets'].str[2:].str.replace(',',''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 3
#       1 # df['Revenue'] = pd.to_numeric(df['Revenue'].str[2:].str.replace(',',''))
#       2 # df['Expenses'] = pd.to_numeric(df['Expenses'].str[2:].str.replace(',',''))
# ----> 3 df['Asset rise'] = pd.to_numeric(df['Asset rise'].str[2:].str.replace(',',''))
#       4 df['Total assets'] = pd.to_numeric(df['Total assets'].str[2:].str.replace(',',''))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\strings\accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\strings\accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df.dtypes
# Out:
# Revenue         int64
# Expenses        int64
# Asset rise      int64
# Total assets    int64
# year            int64
# dtype: object

# %%
df.head()
# Out:
#       Revenue  Expenses  Asset rise  Total assets  year
# Year
# 2004    80129     23463       56666         56666  2004
# 2005   379088    177670      211418        268084  2005
# 2006  1508039    791907      736132       1004216  2006
# 2007  2734909   2077843      654066       1658282  2007
# 2008  5032981   3540724     3519886       5178168  2008

# %% [markdown]
# ### Step 2.g: Visualize data to investigate quality
# - Make a simple plot of **Revenue**, **Expenses** and **Total assets**
# - This will help you spot any outliers

# %%
df[['Revenue','Expenses','Total assets']].plot()
# Out:
# <AxesSubplot: xlabel='Year'>

# %% [markdown]
# ### Step 2.h: Visualize data to investigate quality
# - Make a simple plot of **Asset rise**
# - This will help you spot any outliers

# %%
df['Asset rise'].plot()
# Out:
# <AxesSubplot: xlabel='Year'>
